# %%
import glob
import pandas as pd
import geopandas as gpd
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import folium
import pyproj
import sqlalchemy

# %% [markdown]
# # Getting the data

# %% [markdown]
# ## Sumo wrestlers shusshin (birth place)

# %%
# get data file names
path =r'C:\Users\Maria\Documents\ETLnerds_backup\sumo_demographics\cervus-sumo-banzuke\data'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
sumo_data = pd.concat(dfs, ignore_index=True)

# %%
sumoData_df = sumo_data[["shusshin"]].copy()  #pd.DataFrame({"Total Players": [Num_Players]})

# %%
sumoData_df.head()
# Out:
#    shusshin
# 0  Hokkaido
# 1  Hokkaido
# 2    Aomori
# 3    Aomori
# 4       Mie

# %%
shusshin_df = (sumoData_df.shusshin.value_counts()
                                   .reset_index()
                                   .rename({'index':'shusshin', 
                                            'shusshin':'total_members'},
                                           axis=1)
              )
shusshin_df.head(5)
# Out:
#     shusshin  total_members
# 0      Tokyo          12023
# 1      Osaka          10594
# 2      Aichi          10345
# 3    Fukuoka          10013
# 4  Kagoshima           8146

# %%
type(shusshin_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#sumoData_df.to_csv('SumoData', header=True)

# %%
#set the filepath and load in a shapefile
fp = r"C:\Users\Maria\Downloads\gm-jpn-all_u_2\gm-jpn-all_u_2\polbnda_jpn.shp"
map_df = gpd.read_file(r"C:/Users/Maria/Downloads/gm-jpn-all_u_2/gm-jpn-all_u_2/polbnda_jpn.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
type(map_df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#create clean shusshin column
map_df['shusshin'] = map_df['laa'].apply(lambda s:s.split(' ')[0])

# %%
#view new column
map_df.head()
# Out:
#   f_code  coc        nam             laa       pop   ypc adm_code salb  soc  \
# 0  FA001  JPN  Hokkai Do  Shibetoro Mura -99999999     0    01700  UNK  JPN
# 1  FA001  JPN  Hokkai Do    Wakkanai Shi     41592  2005    01214  UNK  JPN
# 2  FA001  JPN  Hokkai Do       Rebun Cho      3410  2005    01517  UNK  JPN
# 3  FA001  JPN  Hokkai Do      Shana Mura -99999999     0    01699  UNK  JPN
# 4  FA001  JPN  Hokkai Do  Sarufutsu Mura      2940  2005    01511  UNK  JPN
#
#                                             geometry   shusshin
# 0  POLYGON ((148.367599487305 45.22566604614263, ...  Shibetoro
# 1  POLYGON ((141.997406005859 45.23680114746089, ...   Wakkanai
# 2  POLYGON ((141.031692504883 45.27460098266599, ...      Rebun
# 3  POLYGON ((148.342697143555 45.29119873046882, ...      Shana
# 4  POLYGON ((141.997406005859 45.23680114746089, ...  Sarufutsu

# %% [markdown]
# #### So now we have two dataframes ready to go.

# %% [markdown]
# ### First let’s preview what our map looks like with no data in it.

# %% [markdown]
# ### Cool, it’s Japan!

# %% [markdown]
# #### Much better. Now we need to merge our geodata with our cleaned Shusshin dataset. We’ll do that using pd.merge().

# %% [raw]
# shusshin_map_data_df = pd.merge(shusshin_df, map_df,
#                             left_on='shusshin', right_on='shusshin',
#                             how='outer'
#                             )

# %% [raw]
# type(shusshin_map_data_df)

# %% [markdown]
# # Map time!

# %% [markdown]
# #### Let’s start mapping. First we need to do some prep work for Matplotlib. We’ll start by setting a variable to map, setting the range and creating the figure for the map to be drawn in.

# %%
# set a variable that will call whatever column we want to visualize on the map
variable = 'shusshin'
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# %% [markdown]
# ### The stage has been set. Map time.

# %% [raw]
# shusshin_map_data_df.head()

# %% [raw]
# # create map
# shusshin_map_data_df.plot(x=)

# %%
map_df['shusshin'] = map_df['laa'].apply(lambda s:s.split(' ')[0])

# %%
shusshin_df.head(5)
# Out:
#     shusshin  total_members
# 0      Tokyo          12023
# 1      Osaka          10594
# 2      Aichi          10345
# 3    Fukuoka          10013
# 4  Kagoshima           8146

# %%
map_df.head()
# Out:
#   f_code  coc        nam             laa       pop   ypc adm_code salb  soc  \
# 0  FA001  JPN  Hokkai Do  Shibetoro Mura -99999999     0    01700  UNK  JPN
# 1  FA001  JPN  Hokkai Do    Wakkanai Shi     41592  2005    01214  UNK  JPN
# 2  FA001  JPN  Hokkai Do       Rebun Cho      3410  2005    01517  UNK  JPN
# 3  FA001  JPN  Hokkai Do      Shana Mura -99999999     0    01699  UNK  JPN
# 4  FA001  JPN  Hokkai Do  Sarufutsu Mura      2940  2005    01511  UNK  JPN
#
#                                             geometry   shusshin
# 0  POLYGON ((148.367599487305 45.22566604614263, ...  Shibetoro
# 1  POLYGON ((141.997406005859 45.23680114746089, ...   Wakkanai
# 2  POLYGON ((141.031692504883 45.27460098266599, ...      Rebun
# 3  POLYGON ((148.342697143555 45.29119873046882, ...      Shana
# 4  POLYGON ((141.997406005859 45.23680114746089, ...  Sarufutsu

# %%
test_df = pd.merge(map_df, shusshin_df, 
                            on='shusshin', 
                            how='inner'
                            )

# %%
test_df.total_members[0]
# Out:
# 2524

# %% [markdown]
# map_df = map_df.to_crs({'init' : 'epsg:4326'})

# %%
japan_map = folium.Map(location = [36.2, 138.2], zoom_start = 5)

# %%
japan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.GeoJson(test_df, style_function = lambda feature: {}).add_to(japan_map).add_to(japan_map)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-d7edca2fbdb9> in <module>
# ----> 1 folium.GeoJson(test_df, style_function = lambda feature: {}).add_to(japan_map).add_to(japan_map)
#
# ~\Anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, name, overlay, control, show, smooth_factor, highlight_function, tooltip)
#     413             self.embed = True
#     414             if hasattr(data, 'to_crs'):
# --> 415                 data = data.to_crs(epsg='4326')
#     416             self.data = json.loads(json.dumps(data.__geo_interface__))  # noqa
#     417         else:
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     441         else:
#     442             df = self.copy()
# --> 443         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     444         df.geometry = geom
#     445         df.crs = geom.crs
#
# ~\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     302             except TypeError:
#     303                 raise TypeError('Must set either crs or epsg for output.')
# --> 304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     305         proj_out = pyproj.Proj(crs, preserve_units=True)
#     306         project = partial(pyproj.transform, proj_in, proj_out)
#
# ~\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'total_members'
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(8, 9))

test_df.plot(column=variable, cmap='hot', linewidth=1, ax=ax, edgecolor='0.9')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Customizing the map
# #### First off, that axis needs to go.

# %%
# remove the axis
ax.axis('off')
# Out:
# (127.08760757446274, 142.1177909851073, 25.537066555023227, 42.3934659004212)

# %% [markdown]
# #### Then let’s add a title to our map, and some text noting the source. Maps are usually nice to look at, but if you don’t provide context then it doesn’t mean much.

# %%
# add a title
ax.set_title('Shusshiin Locations', fontdict={'fontsize': '25', 'fontweight' : '3'})

# create an annotation for the data source
ax.annotate('Source: Global Map Japan, (Released in 2016)', xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')
# Out:
# Text(0.1, 0.08, 'Source: Global Map Japan, (Released in 2016)')

# %% [markdown]
# ### Beautiful! Still one thing missing though. We should probably add a legend that shows the range of value for the user. This will help it to not look so squished as well.

# %% [markdown]
# #### Pushing files to the SQL database server

# %%
engine = create_engine("sqlite:///sumo.sqlite")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-9eac53bc775d> in <module>
# ----> 1 engine = create_engine("sqlite:///sumo.sqlite")
#
# NameError: name 'create_engine' is not defined
