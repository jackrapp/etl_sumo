# %%
#dependencies
import os
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import datetime as dt

#Python SQL toolkit and ORM
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
sumo_results_df = pd.DataFrame()

# %%
# read in csv files and create dataframe
#for num in range(1983,2019):
    #df = pd.read_csv("cervus-sumo-results/" +str(num)+".csv")
    #sumo_results_df = sumo_results_df.append(df)

# %%
engine = create_engine("sqlite:///sumo.sqlite")

# %%
fout = open("out.csv", "a")
for num in range(1983,2019):
    f = open("cervus-sumo-results/"+str(num)+".csv")
    for line in f:
        fout.write(line)
    f.close()
fout.close()

# %%
df = pd.read_csv('out.csv')

# %%
df
# Out:
#           basho day rikishi1_id rikishi1_rank rikishi1_shikona  \
# 0       1983.01   1        4140          J13w      Chikubayama
# 1       1983.01   1        4306          Ms1e            Ofuji
# 2       1983.01   1        1337          J12w     Tochitsukasa
# 3       1983.01   1        4323          J13e         Shiraiwa
# 4       1983.01   1        4097          J12e       Tamakiyama
# 5       1983.01   1        4319          J11w       Harunafuji
# 6       1983.01   1        4109          J10w       Kotogatake
# 7       1983.01   1        4129          J11e      Hakuryuyama
# 8       1983.01   1        4111          J10e       Zaonishiki
# 9       1983.01   1        4130           J9w          Hachiya
# 10      1983.01   1        1302           J9e       Takamisugi
# 11      1983.01   1        4318           J8w        Tengoyama
# 12      1983.01   1        1361           J8e         Daitetsu
# 13      1983.01   1        4316           J7w       Kakureizan
# ...
